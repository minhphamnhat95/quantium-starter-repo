# %%
import pandas as pd
import dash
from dash import dcc, html
import plotly.express as px

# Load data
df = pd.read_csv("cleaned_daily_sales_data.csv")

# Convert date column to datetime
df["date"] = pd.to_datetime(df["date"])

# Create line chart
fig = px.line(
    df,
    x="date",
    y="sales",
    color="region",
    title="Daily Sales by Region"
)

# Create Dash app
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Sales Dashboard"),
    dcc.Graph(figure=fig)
])

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
